# %% [markdown]
# ### Web scraping

# %%
# Irei tabular informações de cada card de anuncio do site e rodar em cima de cada página.
# Será feito com beautifulsoup

# %% [markdown]
# ### Obtendo o conteúdo  HTML do site
#
#
# site que usarei ->  https://alura-site-scraping.herokuapp.com/index.php

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://alura-site-scraping.herokuapp.com/'

response = urlopen(url)
html = response.read()
html


# Importei bibliotecas, passei parâmetros
# Passei parâmetros do site que quero na variável url
# Criação da variável response
# Abaixo ele mostra o conteúdo html do site
# Out:
# b'<!DOCTYPE html>\r\n<html lang="pt-br">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n\r\n    <title>Alura Motors</title>\r\n\r\n\t<style>\r\n\t\t/*Regra para a animacao*/\r\n\t\t@keyframes spin {\r\n\t\t\t0% { transform: rotate(0deg); }\r\n\t\t\t100% { transform: rotate(360deg); }\r\n\t\t}\r\n\t\t/*Mudando o tamanho do icone de resposta*/\r\n\t\tdiv.glyphicon {\r\n\t\t\tcolor:#6B8E23;\r\n\t\t\tfont-size: 38px;\r\n\t\t}\r\n\t\t/*Classe que mostra a animacao \'spin\'*/\r\n\t\t.loader {\r\n\t\t\tborder: 16px solid #f3f3f3;\r\n\t\t\tborder-radius: 50%;\r\n\t\t\tborder-top: 16px solid #3498db;\r\n\t\t\twidth: 80px;\r\n\t\t\theight: 80px;\r\n\t\t\t-webkit-animation: spin 2s linear infinite;\r\n\t\t\tanimation: spin 2s linear infinite;\r\n\t\t}\r\n\t</style>\r\n\t<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkyc
# ...

# %% [markdown]
# ### Criando um objeto BeautifulSoup
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Alura Motors</title>
# <style>
# 		/*Regra para a animacao*/
# 		@keyframes spin {
# 			0% { transform: rotate(0deg); }
# 			100% { transform: rotate(360deg); }
# 		}
# 		/*Mudando o tamanho do icone de resposta*/
# 		div.glyphicon {
# 			color:#6B8E23;
# 			font-size: 38px;
# 		}
# 		/*Classe que mostra a animacao 'spin'*/
# 		.loader {
# 			border: 16px solid #f3f3f3;
# 			border-radius: 50%;
# 			border-top: 16px solid #3498db;
# 			width: 80px;
# 			height: 80px;
# 			-webkit-animation: spin 2s linear infinite;
# 			animation: spin 2s linear infinite;
# 		}
# 	</style>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# ...

# %%
print(soup.prettify())

# passando este parâmetro ele tratá o conteúdo todo ajustado, identado, ou seja, uma visualização mais organizada.
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <title>
#    Alura Motors
#   </title>
#   <style>
#    /*Regra para a animacao*/
# 		@keyframes spin {
# 			0% { transform: rotate(0deg); }
# 			100% { transform: rotate(360deg); }
# 		}
# 		/*Mudando o tamanho do icone de resposta*/
# 		div.glyphicon {
# 			color:#6B8E23;
# 			font-size: 38px;
# 		}
# 		/*Classe que mostra a animacao 'spin'*/
# 		.loader {
# 			border: 16px solid #f3f3f3;
# 			border-radius: 50%;
# 			border-top: 16px solid #3498db;
# 			width: 80px;
# 			height: 80px;
# 			-webkit-animation: spin 2s linear infinite;
# 			animation: spin 2s linear infinite;
# 		}
#   </style>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# ...

# %% [markdown]
# ### Acessando Tags

# %%
# Iremos acessar as tags chegando ao texto requerido
soup.html.head.title
# Out:
# <title>Alura Motors</title>

# %% [markdown]
# ### Acessando o conteúdo das tags

# %%
soup.html.head.title
# Out:
# <title>Alura Motors</title>

# %%
soup.title.get_text()

#Neste caso, passando este parâmetro ele elimina a tag pegando somente o conteúdo.
# Out:
# 'Alura Motors'

# %%
soup.get_text()

# Tendo uma visualização mais ampla.. ele demostra todo conteúdo que foi requerido.
# Out:
# '\n\n\n\n\nAlura Motors\n\n\n\n\n\n\n\n\n\nYou need to enable JavaScript to run this app.\n\n\n\n\n\nAguarde...\r\n\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMotors\r\n\t\t\t\t\t\t\n\nHello World\nAnúncios\n\n\n\n\n\n\nVeículos de Luxo Novos e Usados - Todas as Marcas\n\n\n\n246 veículos encontrados\n\nPágina 1 de 25\n\n\n\n\n\n\n\n\nLAMBORGHINI AVENTADOR\nUSADO\nMotor 1.8 16v\nAno 1993 - 55.286 km\n\n► 4 X 4\n► Câmera de estacionamento\n► Controle de tração\n► Sensor de estacionamento\n...\n\nBelo Horizonte - MG\n\n\n\nR$ 338.000\n\n\n\n\n\n\n\n\nBMW M2\nUSADO\nMotor 3.0 32v\nAno 2018 - 83.447 km\n\n► Câmera de estacionamento\n► Controle de estabilidade\n► Travas elétricas\n► Freios ABS\n...\n\nBelo Horizonte - MG\n\n\n\nR$ 346.000\n\n\n\n\n\n\n\n\nALFA\nUSADO\nMotor 1.8 16v\nAno 2004 - 19.722 km\n\n► Central multimídia\n► Bancos de couro\n► Rodas de liga\n► Câmera de estacionamento\n...\n\nRio de Janeiro - RJ\n\n\n\nR$ 480.000\n\n\n\n\n\n\n\n\nPUECH\nUSADO\nMotor Diesel V8\nAn
# ...

# %% [markdown]
# ### Acessando os atributos de uma Tag

# %%
soup.img
# Out:
# <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>

# %%
# Quero acessar os atributos dos  códigos acima posso usar o comando abaixo apra acessa de maneira mais organizada.
soup.img.attrs
# Out:
# {'src': 'img/alura-logo.svg',
#  'class': ['d-inline-block', 'align-top'],
#  'alt': 'Alura'}

# %%
soup.img.get('src')
# Out:
# 'img/alura-logo.svg'

# %% [markdown]
# ### Pesquisando com Beautifulsoup

# %%
#metodo findAll
#Mostra uma lista do item procurado
soup.findAll('img')
# Out:
# [<img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg" width="220"/>,
# ...

# %%
#posso tambem percorrer todos os links fazendo um for e ele printa todos os links desejados.

for item in soup.findAll('img', alt='Foto'):
    print(item.get('src'))
# Out:
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg
# ...

# %%
# Utilizando o argumento atributes posso tambem puxar todos os valores

soup.findAll('p')
# Out:
# [<p class="txt-name inline">LAMBORGHINI AVENTADOR</p>,
#  <p class="txt-category badge badge-secondary inline">USADO</p>,
#  <p class="txt-motor">Motor 1.8 16v</p>,
#  <p class="txt-description">Ano 1993 - 55.286 km</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-value">R$ 338.000</p>,
#  <p class="txt-name inline">BMW M2</p>,
#  <p class="txt-category badge badge-secondary inline">USADO</p>,
#  <p class="txt-motor">Motor 3.0 32v</p>,
#  <p class="txt-description">Ano 2018 - 83.447 km</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-value">R$ 346.000</p>,
#  <p class="txt-name inline">ALFA</p>,
#  <p class="txt-category badge badge-secondary inline">USADO</p>,
#  <p class="txt-motor">Motor 1.8 16v</p>,
#  <p class="txt-description">Ano 2004 - 19.722 km</p>,
#  <p class="txt-location">Rio de Janeiro - RJ</p>,
#  <p class="txt-value">R$ 480.000</p>,
#  <p class="txt-name inline">PUECH</p>,
# ...

# %%
#Neste caso quero apenas o valor do veículo

soup.findAll('p',{"class": "txt-value"})
# Out:
# [<p class="txt-value">R$ 338.000</p>,
#  <p class="txt-value">R$ 346.000</p>,
#  <p class="txt-value">R$ 480.000</p>,
#  <p class="txt-value">R$ 133.000</p>,
#  <p class="txt-value">R$ 175.000</p>,
#  <p class="txt-value">R$ 239.000</p>,
#  <p class="txt-value">R$ 115.000</p>,
#  <p class="txt-value">R$ 114.000</p>,
#  <p class="txt-value">R$ 75.000</p>,
#  <p class="txt-value">R$ 117.000</p>]

# %% [markdown]
# ### Buscando por conteúdo de uma TAG

# %%
soup.findAll('p', text = "Belo Horizonte - MG" )
# Out:
# [<p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>]

# %%
### Demostrando que consigo tambem obter todo conteúdo de texto de uma página
soup.findAll(text=True)
# Out:
# ['html',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Alura Motors',
#  '\n',
#  "\r\n\t\t/*Regra para a animacao*/\r\n\t\t@keyframes spin {\r\n\t\t\t0% { transform: rotate(0deg); }\r\n\t\t\t100% { transform: rotate(360deg); }\r\n\t\t}\r\n\t\t/*Mudando o tamanho do icone de resposta*/\r\n\t\tdiv.glyphicon {\r\n\t\t\tcolor:#6B8E23;\r\n\t\t\tfont-size: 38px;\r\n\t\t}\r\n\t\t/*Classe que mostra a animacao 'spin'*/\r\n\t\t.loader {\r\n\t\t\tborder: 16px solid #f3f3f3;\r\n\t\t\tborder-radius: 50%;\r\n\t\t\tborder-top: 16px solid #3498db;\r\n\t\t\twidth: 80px;\r\n\t\t\theight: 80px;\r\n\t\t\t-webkit-animation: spin 2s linear infinite;\r\n\t\t\tanimation: spin 2s linear infinite;\r\n\t\t}\r\n\t",
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\r\n\t\trequisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")\r\n\t',
#  '\n',
#  '\n',
#  '\n',
#  'You need to enable JavaScript to run this app.',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
# ...

# %% [markdown]
# ### Capturando dados do Anúncio

# %%
#Objetivo : Capturar todas as informações dos cards, nome, foto, valor..etc
# raspagem de todas as páginas
#Como ja sabemos os métodos, podemos fazer em um único card e desmembrar para todos os demais.

# %% [markdown]
# ### Obtendo o Html e criando o objeto BeautifulSoup

# %%
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Alura Motors</title>
# <style>
# 		/*Regra para a animacao*/
# 		@keyframes spin {
# 			0% { transform: rotate(0deg); }
# 			100% { transform: rotate(360deg); }
# 		}
# 		/*Mudando o tamanho do icone de resposta*/
# 		div.glyphicon {
# 			color:#6B8E23;
# 			font-size: 38px;
# 		}
# 		/*Classe que mostra a animacao 'spin'*/
# 		.loader {
# 			border: 16px solid #f3f3f3;
# 			border-radius: 50%;
# 			border-top: 16px solid #3498db;
# 			width: 80px;
# 			height: 80px;
# 			-webkit-animation: spin 2s linear infinite;
# 			animation: spin 2s linear infinite;
# 		}
# 	</style>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# ...

# %% [markdown]
# ### Criando variáveis para armazenar informações

# %%
# Iremos criar duas variáveis para raspando no site.
# Aqui onde será armazenada as informações.

cards = []
card = {}

# %% [markdown]
# ### Obtendo dados do primeiro CARD

# %%
# Foi criada a variável anuncio e passado o seguinte parâmetro para obter os dados das tag´s

anuncio = soup.find('div', {'class': 'well card'})
anuncio
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Obtendo o VALOR do veículo anunciado

# %%
anuncio.find('div', {'class':'value-card'})
# Out:
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>

# %%
anuncio.find('p', {'class':'txt-value'}).getText()
# Out:
# 'R$ 338.000'

# %%
card['value'] = anuncio.find('p', {'class':'txt-value'}).getText()

# %%
card
# Out:
# {'value': 'R$ 338.000'}

# %% [markdown]
# ### Obtendo as INFORMAÇÕES sobre o veículo anuncioado

# %%
# Obtenho as informações pelo comando findAll em cima das tags que foram vista anteriormente.
# Após obter essas informações chamo a variável 'infos' e a variável card passando para elas todos os dados que necessito para obter tais informaçãoes .



anuncio.find('div', {'class': 'body-card'}).findAll('p')
# Out:
# [<p class="txt-name inline">LAMBORGHINI AVENTADOR</p>,
#  <p class="txt-category badge badge-secondary inline">USADO</p>,
#  <p class="txt-motor">Motor 1.8 16v</p>,
#  <p class="txt-description">Ano 1993 - 55.286 km</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>]

# %%
infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')

# %%
for info in infos:
    card[info.get('class')[0].split('-')[-1]] = info.get_text()

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG'}

# %% [markdown]
# ### Obtendo Acessórios do veículo e retirando dados indesejáveis

# %%
anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items.pop()
# Out:
# <li class="txt-items">...</li>

# %%
#Executando este comando, teremos eliminado a seta.

for item in items:
    print(item.getText().replace('► ', ''))
# Out:
# 4 X 4
# Câmera de estacionamento
# Controle de tração
# Sensor de estacionamento

# %%
acessorios = []
for item in items:
    acessorios.append(item.getText().replace('►',''))
                      
acessorios
# Out:
# [' 4 X 4',
#  ' Câmera de estacionamento',
#  ' Controle de tração',
#  ' Sensor de estacionamento']

# %%
card['items'] = acessorios

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG',
#  'items': [' 4 X 4',
#   ' Câmera de estacionamento',
#   ' Controle de tração',
#   ' Sensor de estacionamento']}

# %% [markdown]
# ### Criando um DataFrame com os dados coletados do site

# %%
# Agora vamos importar o pandas e tratar do jeito que queremos.
# Em seguida vamos salvar em um local de destino como um arquivo csv

import pandas as pd

dataset = pd.DataFrame(card)
dataset
# Out:
#         value                   name category          motor  \
# 0  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 1  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 2  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 3  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
#
#             description             location                      items
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG                      4 X 4
# 1  Ano 1993 - 55.286 km  Belo Horizonte - MG   Câmera de estacionamento
# 2  Ano 1993 - 55.286 km  Belo Horizonte - MG         Controle de tração
# 3  Ano 1993 - 55.286 km  Belo Horizonte - MG   Sensor de estacionamento

# %%
dataset = pd.DataFrame.from_dict(card, orient = 'index').T
dataset
# Out:
#         value                   name category          motor  \
# 0  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
#
#             description             location  \
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG
#
#                                                items
# 0  [ 4 X 4,  Câmera de estacionamento,  Controle ...

# %%
dataset.to_csv('C:/Users/Cleiton Silva/Documents/output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# ### Obtendo foto do anúncio

# %%
# Ao inspecionar a página consigo localizar a div da imagem puxando a informação que preciso
# Armazeno as informações na variável
# Printo as informações que puxei e tenho acesso a ela
# Entao eu passo as informações concatenando junto ao meu local de armazenamento

image = anuncio.find('div', {'class': 'image-card'}).img
image
# Out:
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>

# %%
image.get('src')
# Out:
# 'https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg'

# %%
print(image.get('src'))
# Out:
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg

# %% [markdown]
# ##### Para acessar e salvar a FOTO do anuncio
#
# https://docs.python.org/3/library/urllib.request.html#urllib.request.urlretrieve

# %%
image.get('src').split('/')[-1]
# Out:
# 'lamborghini-aventador-2932196__340.jpg'

# %%
from urllib.request import urlretrieve

urlretrieve(image.get('src'), 'C:/Users/Cleiton Silva/Documents/output/img/' + image.get('src').split('/')[-1])
# Out:
# ('C:/Users/Cleiton Silva/Documents/output/img/lamborghini-aventador-2932196__340.jpg',
#  <http.client.HTTPMessage at 0x1b394e04460>)

# %% [markdown]
# ### Obtendo os dados de TODOS os anuncios de uma página

# %%
#Identificando as informações no HTML
# Localizando os cards
# verificando quantidade de cards nesta pagina
# Criando a variávl 'anuncios' e fazendo um for sobre eles organizadamente.

soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")
# Out:
# [<div class="well card">
#  <div class="col-md-3 image-card">
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
#  </div>
#  <div class="col-md-6 body-card">
#  <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
#  <p class="txt-category badge badge-secondary inline">USADO</p>
#  <p class="txt-motor">Motor 1.8 16v</p>
#  <p class="txt-description">Ano 1993 - 55.286 km</p>
#  <ul class="lst-items">
#  <li class="txt-items">► 4 X 4</li>
#  <li class="txt-items">► Câmera de estacionamento</li>
#  <li class="txt-items">► Controle de tração</li>
#  <li class="txt-items">► Sensor de estacionamento</li>
#  <li class="txt-items">...</li>
#  </ul>
#  <p class="txt-location">Belo Horizonte - MG</p>
#  </div>
#  <div class="col-md-3 value-card">
#  <div class="value">
#  <p class="txt-value">R$ 338.000</p>
#  </div>
#  </div>
#  </div>,
# ...

# %%
len(soup.find('div', {"id": "container-cards"}).findAll('div', class_="card"))
# Out:
# 10

# %%
anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

# %%
for anuncio in anuncios:
    print(str(anuncio) + "\n\n")
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# ...

# %% [markdown]
# ### Criando uma rotina de scraping

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

# Obtendo o HTML
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')

# Obtendo as TAGs de interesse
anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

# Coletando as informações dos cards
for anuncio in anuncios:
    card = {}
    
    # Valor
    card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

    # Informações
    infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
    for info in infos:
        card[info.get('class')[0].split('-')[-1]] = info.get_text()

    # Acessórios
    items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
    items.pop()
    acessorios = []
    for item in items:
        acessorios.append(item.get_text().replace('► ', ''))
    card['items'] = acessorios

    # Adicionando resultado à lista cards
    
    cards.append(card)
    
    
    # Imagens
    image = anuncio.find('div', {'class': 'image-card'}).img
    urlretrieve(image.get('src'), 'C:/Users/Cleiton Silva/Documents/output/img/' + image.get('src').split('/')[-1])  

# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('C:/Users/Cleiton Silva/Documents/output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#         value                    name category            motor  \
# 0  R$ 338.000   LAMBORGHINI AVENTADOR    USADO    Motor 1.8 16v
# 1  R$ 346.000                  BMW M2    USADO    Motor 3.0 32v
# 2  R$ 480.000                    ALFA    USADO    Motor 1.8 16v
# 3  R$ 133.000                   PUECH    USADO  Motor Diesel V8
# 4  R$ 175.000  LAMBORGHINI MURCIELAGO    USADO     Motor 1.0 8v
# 5  R$ 239.000            ASTON MARTIN    USADO  Motor Diesel V6
# 6  R$ 115.000                     TVR    USADO  Motor 4.0 Turbo
# 7  R$ 114.000               EXCALIBUR    USADO    Motor 3.0 32v
# 8   R$ 75.000                 MCLAREN     NOVO     Motor Diesel
# 9  R$ 117.000                  TOYOTA    USADO  Motor 4.0 Turbo
#
#             description             location  \
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG
# 1  Ano 2018 - 83.447 km  Belo Horizonte - MG
# 2  Ano 2004 - 19.722 km  Rio de Janeiro - RJ
# 3  Ano 1992 - 34.335 km       São Paulo - SP
# ...

# %%
cards

# %% [markdown]
#   ### Identificando os dados de TODA  a pagina ||   25 páginas, 246 veículos

# %%
# Identificando as informações no HTML


soup.find('span', class_="info-pages")
# Out:
# <span class="info-pages">Página 1 de 25</span>

# %%
soup.find('span', class_="info-pages").get_text()
# Out:
# 'Página 1 de 25'

# %%
soup.find('span', class_="info-pages").get_text().split()
# Out:
# ['Página', '1', 'de', '25']

# %%
soup.find('span', class_="info-pages").get_text().split()[-1]
# Out:
# '25'

# %%
int(soup.find('span', class_="info-pages").get_text().split()[-1])
# Out:
# 25

# %% [markdown]
# ### Criando uma rotina de Scraping

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

## Obtendo o HTML total das páginas
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
pages = int(soup.find('span', class_="info-pages").get_text().split()[-1])

## Iterando por todas as páginasdo site
for i in range(pages):

    ## Obtendo o HTML
    response = urlopen('https://alura-site-scraping.herokuapp.com/index.php?page=' + str (i + 1))
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')

    # Obtendo as TAGs de interesse
    anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

    # Coletando as informações dos CARDS
    for anuncio in anuncios:
        card = {}

        # Valor
        card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

        # Informações
        infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
        for info in infos:
            card[info.get('class')[0].split('-')[-1]] = info.get_text()

        # Acessórios
        items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
        items.pop()
        acessorios = []
        for item in items:
            acessorios.append(item.get_text().replace('► ', ''))
        card['items'] = acessorios

        # Adicionando resultado à lista cards

        cards.append(card)


        # Imagens
        image = anuncio.find('div', {'class': 'image-card'}).img
        urlretrieve(image.get('src'), 'C:/Users/Cleiton Silva/Documents/output/img/' + image.get('src').split('/')[-1])  

    
# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('C:/Users/Cleiton Silva/Documents/output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#           value                    name category            motor  \
# 0    R$ 338.000   LAMBORGHINI AVENTADOR    USADO    Motor 1.8 16v
# 1    R$ 346.000                  BMW M2    USADO    Motor 3.0 32v
# 2    R$ 480.000                    ALFA    USADO    Motor 1.8 16v
# 3    R$ 133.000                   PUECH    USADO  Motor Diesel V8
# 4    R$ 175.000  LAMBORGHINI MURCIELAGO    USADO     Motor 1.0 8v
# ..          ...                     ...      ...              ...
# 241  R$ 489.000           SUV REAR TIRE    USADO    Motor 3.0 32v
# 242  R$ 427.000                 ANTIQUE     NOVO    Motor 2.0 16v
# 243  R$ 203.000                   SPORT    USADO    Motor 2.0 16v
# 244  R$ 474.000                IMPERIAL    USADO    Motor 1.8 16v
# 245  R$ 366.000          KIA SPORTS CAR    USADO    Motor 3.0 32v
#
#                description             location  \
# 0     Ano 1993 - 55.286 km  Belo Horizonte - MG
# 1     Ano 2018 - 83.447 km  Belo Horizonte - MG
# ...

# %%
cards
# Out:
# [{'value': 'R$ 338.000',
#   'name': 'LAMBORGHINI AVENTADOR',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1993 - 55.286 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['4 X 4',
#    'Câmera de estacionamento',
#    'Controle de tração',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 346.000',
#   'name': 'BMW M2',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2018 - 83.447 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmera de estacionamento',
#    'Controle de estabilidade',
#    'Travas elétricas',
#    'Freios ABS']},
#  {'value': 'R$ 480.000',
#   'name': 'ALFA',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2004 - 19.722 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Central multimídia',
#    'Bancos de couro',
#    'Rodas de liga',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 133.000',
#   'name': 'PUECH',
#   'category': 'USADO',
# ...

# %%
 #Conclusão. 
 # Foi feito uma raspagem completa do site, mostrando passo a passo.
 # Diante disso coletamos dados do veículo, imagens, valores, categoria, localização e detalhes.
 # criamos um arquivo csv e armazenamos todas as imagens dentro de uma pasta.
